# %% [markdown]
# # 可视化文件夹中的图像
#
# 同济子豪兄 https://space.bilibili.com/1900783
#
# 代码运行[云GPU平台](https://featurize.cn/?s=d7ce99f842414bfcaea5662a97581bd1)
#
# 2022-7-31

# %% [markdown]
# ## 导入工具包

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from mpl_toolkits.axes_grid1 import ImageGrid
# %matplotlib inline

import numpy as np
import math
import os

import cv2

from tqdm import tqdm

# %% [markdown]
# ## 指定要可视化图像的文件夹

# %%
folder_path = r'D:\dataset\sr\train\parasitized'

# %%
# 可视化图像的个数
N = 36

# %%
# n 行 n 列
n = math.floor(np.sqrt(N))
n
# Out:
# 6

# %% [markdown]
# ## 读取文件夹中的所有图像

# %%
images = []
for each_img in os.listdir(folder_path)[:N]:
    img_path = os.path.join(folder_path, each_img)
    img_bgr = cv2.imread(img_path)
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    images.append(img_rgb)

# %%
len(images)
# Out:
# 36

# %% [markdown]
# ## 画图

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid

# 假设 images 是一个包含多个图像的列表
n = 4  # 你想在网格中每行、每列显示的图像数量
fig = plt.figure(figsize=(10, 10))
grid = ImageGrid(fig, 111,  # 类似于绘制子图 subplot(111)
                 nrows_ncols=(n, n),  # 创建 n 行 n 列的 axes 网格
                 axes_pad=0.1,  # 网格间距
                 share_all=True
                 )

# 遍历每张图像
for ax, im in zip(grid, images):
    ax.imshow(im)
    ax.axis('on')  # 显示坐标轴

plt.tight_layout()
plt.show()
# Out:
# C:\Users\61640\AppData\Local\Temp\ipykernel_10924\3343001216.py:18: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
